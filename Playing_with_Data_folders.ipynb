# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/Breast Cancer Project/new_master_dataset.csv")
df
# Out:
# Mounted at /content/drive
#       mag                                               path  \
# 0     100  /content/drive/MyDrive/Breast Cancer Project/b...
# 1     100  /content/drive/MyDrive/Breast Cancer Project/b...
# 2     100  /content/drive/MyDrive/Breast Cancer Project/b...
# 3     100  /content/drive/MyDrive/Breast Cancer Project/b...
# 4     100  /content/drive/MyDrive/Breast Cancer Project/b...
# ...   ...                                                ...
# 7904  400  /content/drive/MyDrive/Breast Cancer Project/b...
# 7905  400  /content/drive/MyDrive/Breast Cancer Project/b...
# 7906  400  /content/drive/MyDrive/Breast Cancer Project/b...
# 7907  400  /content/drive/MyDrive/Breast Cancer Project/b...
# 7908  400  /content/drive/MyDrive/Breast Cancer Project/b...
#
#                             filename      class slide_id tumor_type
# 0     SOB_B_A-14-22549CD-100-001.png     benign  22549CD          A
# 1     SOB_B_A-14-22549CD-100-002.png     benign  22549CD          A
# ...

# %%
import pandas as pd

# Assuming df is your DataFrame containing the column 'slide_id'
# Count the total number of unique slide IDs
total_unique_slide_ids = df['slide_id'].nunique()

print("Total unique slide IDs:", total_unique_slide_ids)
# Out:
# Total unique slide IDs: 81

# %%
df_mag_100 = df[df['mag'] == 100]
df_mag_200 = df[df['mag'] == 200]
df_mag_40 = df[df['mag'] == 40]
df_mag_400 = df[df['mag'] == 400]

# %%
import pandas as pd
import numpy as np

def split_and_count_tumor_types(seed):
    # Shuffle the slide_ids to ensure randomness with the given random seed
    slide_ids = df_mag['slide_id'].unique()
    np.random.seed(seed)
    np.random.shuffle(slide_ids)

    # Determine the number of slide_ids for each set
    train_size = 42
    test_size = 25
    validation_size = 15

    # Assign slide_ids to train, test, and validation sets
    train_slide_ids = slide_ids[:train_size]
    test_slide_ids = slide_ids[train_size:train_size + test_size]
    validation_slide_ids = slide_ids[train_size + test_size:train_size + test_size + validation_size]

    # Create new DataFrames for train, test, and validation sets
    train_df = df_mag[df_mag['slide_id'].isin(train_slide_ids)]
    test_df = df_mag[df_mag['slide_id'].isin(test_slide_ids)]
    validation_df = df_mag[df_mag['slide_id'].isin(validation_slide_ids)]

    # Count of unique tumor types in train_df, test_df, and validation_df
    count_unique_tumor_types_train = len(train_df['tumor_type'].unique())
    count_unique_tumor_types_test = len(test_df['tumor_type'].unique())
    count_unique_tumor_types_validation = len(validation_df['tumor_type'].unique())

    return count_unique_tumor_types_train, count_unique_tumor_types_test, count_unique_tumor_types_validation

# %%
# Iterate through different random seeds to find the desired result
df_mag = df_mag_400
desired_count = 8
random_seed = None
for seed in range(1000):  # Try different seeds
    train_count, test_count, val_count = split_and_count_tumor_types(seed)
    if train_count == test_count == val_count == desired_count:
        random_seed = seed
        break

print("Random seed:", random_seed)
# Out:
# Random seed: 14

# %%
import pandas as pd
import numpy as np

slide_ids = df_mag_100['slide_id'].unique()
np.random.seed(14)  # Setting the random seed for reproducibility
np.random.shuffle(slide_ids)

# Determine the number of slide_ids for each set
train_size = 42
test_size = 25
validation_size = 15

# Assign slide_ids to train, test, and validation sets
train_slide_ids = slide_ids[:train_size]
test_slide_ids = slide_ids[train_size:train_size+test_size]
validation_slide_ids = slide_ids[train_size+test_size:train_size+test_size+validation_size]

# Create new DataFrames for train, test, and validation sets
train_df_100 = df_mag_100[df_mag_100['slide_id'].isin(train_slide_ids)]
test_df_100 = df_mag_100[df_mag_100['slide_id'].isin(test_slide_ids)]
val_df_100 = df_mag_100[df_mag_100['slide_id'].isin(validation_slide_ids)]

# Print the sizes of the train, test, and validation sets
print("Train set size:", len(train_df_100))
print("Test set size:", len(test_df_100))
print("Validation set size:", len(val_df_100))

# Count of unique tumor types in train_df_100
count_unique_tumor_types_train = len(train_df_100['tumor_type'].unique())

# Count of unique tumor types in test_df
count_unique_tumor_types_test = len(test_df_100['tumor_type'].unique())

# Count of unique tumor types in validation_df
count_unique_tumor_types_validation = len(val_df_100['tumor_type'].unique())

# Print count of unique tumor types for each set
print("Count of unique tumor types in train set:", count_unique_tumor_types_train)
print("Count of unique tumor types in test set:", count_unique_tumor_types_test)
print("Count of unique tumor types in validation set:", count_unique_tumor_types_validation)
# Out:
# Train set size: 1127
# Test set size: 567
# Validation set size: 387
# Count of unique tumor types in train set: 8
# Count of unique tumor types in test set: 8
# Count of unique tumor types in validation set: 8

# %%
import pandas as pd
import numpy as np

slide_ids = df_mag_200['slide_id'].unique()
np.random.seed(14)  # Setting the random seed for reproducibility
np.random.shuffle(slide_ids)

# Determine the number of slide_ids for each set
train_size = 42
test_size = 25
validation_size = 15

# Assign slide_ids to train, test, and validation sets
train_slide_ids = slide_ids[:train_size]
test_slide_ids = slide_ids[train_size:train_size+test_size]
validation_slide_ids = slide_ids[train_size+test_size:train_size+test_size+validation_size]

# Create new DataFrames for train, test, and validation sets
train_df_200 = df_mag[df_mag['slide_id'].isin(train_slide_ids)]
test_df_200 = df_mag[df_mag['slide_id'].isin(test_slide_ids)]
val_df_200 = df_mag[df_mag['slide_id'].isin(validation_slide_ids)]

# Print the sizes of the train, test, and validation sets
print("Train set size:", len(train_df_200))
print("Test set size:", len(test_df_200))
print("Validation set size:", len(val_df_200))

# Count of unique tumor types in train_df_200
count_unique_tumor_types_train = len(train_df_200['tumor_type'].unique())

# Count of unique tumor types in test_df
count_unique_tumor_types_test = len(test_df_200['tumor_type'].unique())

# Count of unique tumor types in validation_df
count_unique_tumor_types_validation = len(val_df_200['tumor_type'].unique())

# Print count of unique tumor types for each set
print("Count of unique tumor types in train set:", count_unique_tumor_types_train)
print("Count of unique tumor types in test set:", count_unique_tumor_types_test)
print("Count of unique tumor types in validation set:", count_unique_tumor_types_validation)
# Out:
# Train set size: 961
# Test set size: 522
# Validation set size: 337
# Count of unique tumor types in train set: 8
# Count of unique tumor types in test set: 8
# Count of unique tumor types in validation set: 8

# %%
import pandas as pd
import numpy as np

df_mag = df_mag_40
slide_ids = df_mag['slide_id'].unique()
np.random.seed(14)  # Setting the random seed for reproducibility
np.random.shuffle(slide_ids)

# Determine the number of slide_ids for each set
train_size = 42
test_size = 25
validation_size = 15

# Assign slide_ids to train, test, and validation sets
train_slide_ids = slide_ids[:train_size]
test_slide_ids = slide_ids[train_size:train_size+test_size]
validation_slide_ids = slide_ids[train_size+test_size:train_size+test_size+validation_size]

# Create new DataFrames for train, test, and validation sets
train_df_40 = df_mag[df_mag['slide_id'].isin(train_slide_ids)]
test_df_40 = df_mag[df_mag['slide_id'].isin(test_slide_ids)]
val_df_40 = df_mag[df_mag['slide_id'].isin(validation_slide_ids)]

# Print the sizes of the train, test, and validation sets
print("Train set size:", len(train_df_40))
print("Test set size:", len(test_df_40))
print("Validation set size:", len(val_df_40))

# Count of unique tumor types in train_df
count_unique_tumor_types_train = len(train_df_40['tumor_type'].unique())

# Count of unique tumor types in test_df
count_unique_tumor_types_test = len(test_df_40['tumor_type'].unique())

# Count of unique tumor types in validation_df
count_unique_tumor_types_validation = len(val_df_40['tumor_type'].unique())

# Print count of unique tumor types for each set
print("Count of unique tumor types in train set:", count_unique_tumor_types_train)
print("Count of unique tumor types in test set:", count_unique_tumor_types_test)
print("Count of unique tumor types in validation set:", count_unique_tumor_types_validation)
# Out:
# Train set size: 1049
# Test set size: 560
# Validation set size: 386
# Count of unique tumor types in train set: 8
# Count of unique tumor types in test set: 8
# Count of unique tumor types in validation set: 8

# %%
import pandas as pd
import numpy as np

df_mag = df_mag_400
slide_ids = df_mag['slide_id'].unique()
np.random.seed(14)  # Setting the random seed for reproducibility
np.random.shuffle(slide_ids)

# Determine the number of slide_ids for each set
train_size = 42
test_size = 25
validation_size = 15

# Assign slide_ids to train, test, and validation sets
train_slide_ids = slide_ids[:train_size]
test_slide_ids = slide_ids[train_size:train_size+test_size]
validation_slide_ids = slide_ids[train_size+test_size:train_size+test_size+validation_size]

# Create new DataFrames for train, test, and validation sets
train_df_400 = df_mag[df_mag['slide_id'].isin(train_slide_ids)]
test_df_400 = df_mag[df_mag['slide_id'].isin(test_slide_ids)]
val_df_400 = df_mag[df_mag['slide_id'].isin(validation_slide_ids)]

# Print the sizes of the train, test, and validation sets
print("Train set size:", len(train_df_400))
print("Test set size:", len(test_df_400))
print("Validation set size:", len(val_df_400))

# Count of unique tumor types in train_df
count_unique_tumor_types_train = len(train_df_400['tumor_type'].unique())

# Count of unique tumor types in test_df
count_unique_tumor_types_test = len(test_df_400['tumor_type'].unique())

# Count of unique tumor types in validation_df
count_unique_tumor_types_validation = len(val_df_400['tumor_type'].unique())

# Print count of unique tumor types for each set
print("Count of unique tumor types in train set:", count_unique_tumor_types_train)
print("Count of unique tumor types in test set:", count_unique_tumor_types_test)
print("Count of unique tumor types in validation set:", count_unique_tumor_types_validation)
# Out:
# Train set size: 961
# Test set size: 522
# Validation set size: 337
# Count of unique tumor types in train set: 8
# Count of unique tumor types in test set: 8
# Count of unique tumor types in validation set: 8

# %%
import pandas as pd
from sklearn.utils import shuffle

# Shuffle training set with random state 42
train_df_100_shuffled = shuffle(train_df_100, random_state=42)
# Shuffle testing set with random state 42
test_df_100_shuffled = shuffle(test_df_100, random_state=42)
# Shuffle validation set with random state 42
val_df_100_shuffled = shuffle(val_df_100, random_state=42)

# Save shuffled dataframes to CSV
train_df_100_shuffled.to_csv('/content/drive/MyDrive/Breast Cancer Project/Mag100/train_df_100.csv', index=False)
test_df_100_shuffled.to_csv('/content/drive/MyDrive/Breast Cancer Project/Mag100/test_df_100.csv', index=False)
val_df_100_shuffled.to_csv('/content/drive/MyDrive/Breast Cancer Project/Mag100/val_df_100.csv', index=False)

# %%
import pandas as pd
from sklearn.utils import shuffle

# Shuffle training set with random state 42
train_df_100_shuffled = shuffle(train_df_100, random_state=42)
# Shuffle testing set with random state 42
test_df_100_shuffled = shuffle(test_df_100, random_state=42)
# Shuffle validation set with random state 42
val_df_100_shuffled = shuffle(val_df_100, random_state=42)

# Save shuffled dataframes to CSV
train_df_100_shuffled.to_csv('/content/drive/MyDrive/Breast Cancer Project/Mag100/train_df_100.csv', index=False)
test_df_100_shuffled.to_csv('/content/drive/MyDrive/Breast Cancer Project/Mag100/test_df_100.csv', index=False)
val_df_100_shuffled.to_csv('/content/drive/MyDrive/Breast Cancer Project/Mag100/val_df_100.csv', index=False)

# %%
import pandas as pd
from sklearn.utils import shuffle

# Shuffle training set with random state 42 for each size
train_df_200_shuffled = shuffle(train_df_200, random_state=42)
train_df_40_shuffled = shuffle(train_df_40, random_state=42)
train_df_400_shuffled = shuffle(train_df_400, random_state=42)

# Shuffle testing set with random state 42 for each size
test_df_200_shuffled = shuffle(test_df_200, random_state=42)
test_df_40_shuffled = shuffle(test_df_40, random_state=42)
test_df_400_shuffled = shuffle(test_df_400, random_state=42)

# Shuffle validation set with random state 42 for each size
val_df_200_shuffled = shuffle(val_df_200, random_state=42)
val_df_40_shuffled = shuffle(val_df_40, random_state=42)
val_df_400_shuffled = shuffle(val_df_400, random_state=42)

# Save shuffled dataframes to CSV for each size
train_df_200_shuffled.to_csv('/content/drive/MyDrive/Breast Cancer Project/Mag200/train_df_200.csv', index=False)
test_df_200_shuffled.to_csv('/content/drive/MyDrive/Breast Cancer Project/Mag200/test_df_200.csv', index=False)
val_df_200_shuffled.to_csv('/content/drive/MyDrive/Breast Cancer Project/Mag200/val_df_200.csv', index=False)

train_df_40_shuffled.to_csv('/content/drive/MyDrive/Breast Cancer Project/Mag40/train_df_40.csv', index=False)
test_df_40_shuffled.to_csv('/content/drive/MyDrive/Breast Cancer Project/Mag40/test_df_40.csv', index=False)
val_df_40_shuffled.to_csv('/content/drive/MyDrive/Breast Cancer Project/Mag40/val_df_40.csv', index=False)

train_df_400_shuffled.to_csv('/content/drive/MyDrive/Breast Cancer Project/Mag400/train_df_400.csv', index=False)
test_df_400_shuffled.to_csv('/content/drive/MyDrive/Breast Cancer Project/Mag400/test_df_400.csv', index=False)
val_df_400_shuffled.to_csv('/content/drive/MyDrive/Breast Cancer Project/Mag400/val_df_400.csv', index=False)

# %%
import pandas as pd
import os
import shutil

def create_folders_and_move_images(csv_file_path, output_folder):
    # Load CSV file into a DataFrame
    df = pd.read_csv(csv_file_path)

    # Create output folders for each class
    for class_name in df['class'].unique():
        class_folder = os.path.join(output_folder, class_name)
        os.makedirs(class_folder, exist_ok=True)

    # Move images to their respective class folders
    for index, row in df.iterrows():
        image_path = row['path']
        class_name = row['class']

        # Extract image filename from the image path
        image_filename = os.path.basename(image_path)

        # Define source and destination paths
        source_path = image_path
        destination_path = os.path.join(output_folder, class_name, image_filename)

        # Move the image file to its respective class folder
        shutil.copy(source_path, destination_path)

# %%
# df_100
csv_file_path1 = '/content/drive/MyDrive/Breast Cancer Project/Mag200/train_df_200.csv'
output_folder1 = '/content/drive/MyDrive/Breast Cancer Project/Akash Split/Mag200/train'

csv_file_path2 = '/content/drive/MyDrive/Breast Cancer Project/Mag200/test_df_200.csv'
output_folder2 = '/content/drive/MyDrive/Breast Cancer Project/Akash Split/Mag200/test'

csv_file_path3 = '/content/drive/MyDrive/Breast Cancer Project/Mag200/val_df_200.csv'
output_folder3 = '/content/drive/MyDrive/Breast Cancer Project/Akash Split/Mag200/val'

create_folders_and_move_images(csv_file_path1, output_folder1)
create_folders_and_move_images(csv_file_path2, output_folder2)
create_folders_and_move_images(csv_file_path3, output_folder3)

# %%
# df_100
csv_file_path1 = '/content/drive/MyDrive/Breast Cancer Project/Mag100/train_df_100.csv'
output_folder1 = '/content/drive/MyDrive/Breast Cancer Project/Akash Split/Mag100/train'

csv_file_path2 = '/content/drive/MyDrive/Breast Cancer Project/Mag100/test_df_100.csv'
output_folder2 = '/content/drive/MyDrive/Breast Cancer Project/Akash Split/Mag100/test'

csv_file_path3 = '/content/drive/MyDrive/Breast Cancer Project/Mag100/val_df_100.csv'
output_folder3 = '/content/drive/MyDrive/Breast Cancer Project/Akash Split/Mag100/val'

create_folders_and_move_images(csv_file_path1, output_folder1)
create_folders_and_move_images(csv_file_path2, output_folder2)
create_folders_and_move_images(csv_file_path3, output_folder3)

# %%
# df_400
csv_file_path1 = '/content/drive/MyDrive/Breast Cancer Project/Mag400/train_df_400.csv'
output_folder1 = '/content/drive/MyDrive/Breast Cancer Project/Akash Split/Mag400/train'

csv_file_path2 = '/content/drive/MyDrive/Breast Cancer Project/Mag400/test_df_400.csv'
output_folder2 = '/content/drive/MyDrive/Breast Cancer Project/Akash Split/Mag400/test'

csv_file_path3 = '/content/drive/MyDrive/Breast Cancer Project/Mag400/val_df_400.csv'
output_folder3 = '/content/drive/MyDrive/Breast Cancer Project/Akash Split/Mag400/val'

create_folders_and_move_images(csv_file_path1, output_folder1)
create_folders_and_move_images(csv_file_path2, output_folder2)
create_folders_and_move_images(csv_file_path3, output_folder3)

# %%
# df_400
csv_file_path1 = '/content/drive/MyDrive/Breast Cancer Project/Mag40/train_df_40.csv'
output_folder1 = '/content/drive/MyDrive/Breast Cancer Project/Akash Split/Mag40/train'

csv_file_path2 = '/content/drive/MyDrive/Breast Cancer Project/Mag40/test_df_40.csv'
output_folder2 = '/content/drive/MyDrive/Breast Cancer Project/Akash Split/Mag40/test'

csv_file_path3 = '/content/drive/MyDrive/Breast Cancer Project/Mag40/val_df_40.csv'
output_folder3 = '/content/drive/MyDrive/Breast Cancer Project/Akash Split/Mag40/val'

create_folders_and_move_images(csv_file_path1, output_folder1)
create_folders_and_move_images(csv_file_path2, output_folder2)
create_folders_and_move_images(csv_file_path3, output_folder3)

# %%
import pandas as pd
import os
import shutil

def create_folders_and_move_images(csv_file_path, output_folder):
    # Load CSV file into a DataFrame
    df = pd.read_csv(csv_file_path)

    # Create output folders for each tumor_type
    for class_name in df['tumor_type'].unique():
        class_folder = os.path.join(output_folder, class_name)
        os.makedirs(class_folder, exist_ok=True)

    # Move images to their respective tumor_type folders
    for index, row in df.iterrows():
        image_path = row['path']
        class_name = row['tumor_type']

        # Extract image filename from the image path
        image_filename = os.path.basename(image_path)

        # Define source and destination paths
        source_path = image_path
        destination_path = os.path.join(output_folder, class_name, image_filename)

        # Move the image file to its respective tumor_type folder
        shutil.copy(source_path, destination_path)

# %%
# df_200
csv_file_path1 = '/content/drive/MyDrive/Breast Cancer Project/Mag200/train_df_200.csv'
output_folder1 = '/content/drive/MyDrive/Breast Cancer Project/Akash Split/Multi Class/Mag200/train'

csv_file_path2 = '/content/drive/MyDrive/Breast Cancer Project/Mag200/test_df_200.csv'
output_folder2 = '/content/drive/MyDrive/Breast Cancer Project/Akash Split/Multi Class/Mag200/test'

csv_file_path3 = '/content/drive/MyDrive/Breast Cancer Project/Mag200/val_df_200.csv'
output_folder3 = '/content/drive/MyDrive/Breast Cancer Project/Akash Split/Multi Class/Mag200/val'

create_folders_and_move_images(csv_file_path1, output_folder1)
create_folders_and_move_images(csv_file_path2, output_folder2)
create_folders_and_move_images(csv_file_path3, output_folder3)

# %%
# df_100
csv_file_path1 = '/content/drive/MyDrive/Breast Cancer Project/Mag100/train_df_100.csv'
output_folder1 = '/content/drive/MyDrive/Breast Cancer Project/Akash Split/Multi Class/Mag100/train'

csv_file_path2 = '/content/drive/MyDrive/Breast Cancer Project/Mag100/test_df_100.csv'
output_folder2 = '/content/drive/MyDrive/Breast Cancer Project/Akash Split/Multi Class/Mag100/test'

csv_file_path3 = '/content/drive/MyDrive/Breast Cancer Project/Mag100/val_df_100.csv'
output_folder3 = '/content/drive/MyDrive/Breast Cancer Project/Akash Split/Multi Class/Mag100/val'

create_folders_and_move_images(csv_file_path1, output_folder1)
create_folders_and_move_images(csv_file_path2, output_folder2)
create_folders_and_move_images(csv_file_path3, output_folder3)

# %%
# df_400
csv_file_path1 = '/content/drive/MyDrive/Breast Cancer Project/Mag400/train_df_400.csv'
output_folder1 = '/content/drive/MyDrive/Breast Cancer Project/Akash Split/Multi Class/Mag400/train'

csv_file_path2 = '/content/drive/MyDrive/Breast Cancer Project/Mag400/test_df_400.csv'
output_folder2 = '/content/drive/MyDrive/Breast Cancer Project/Akash Split/Multi Class/Mag400/test'

csv_file_path3 = '/content/drive/MyDrive/Breast Cancer Project/Mag400/val_df_400.csv'
output_folder3 = '/content/drive/MyDrive/Breast Cancer Project/Akash Split/Multi Class/Mag400/val'

create_folders_and_move_images(csv_file_path1, output_folder1)
create_folders_and_move_images(csv_file_path2, output_folder2)
create_folders_and_move_images(csv_file_path3, output_folder3)

# %%
# df_40
csv_file_path1 = '/content/drive/MyDrive/Breast Cancer Project/Mag40/train_df_40.csv'
output_folder1 = '/content/drive/MyDrive/Breast Cancer Project/Akash Split/Multi Class/Mag40/train'

csv_file_path2 = '/content/drive/MyDrive/Breast Cancer Project/Mag40/test_df_40.csv'
output_folder2 = '/content/drive/MyDrive/Breast Cancer Project/Akash Split/Multi Class/Mag40/test'

csv_file_path3 = '/content/drive/MyDrive/Breast Cancer Project/Mag40/val_df_40.csv'
output_folder3 = '/content/drive/MyDrive/Breast Cancer Project/Akash Split/Multi Class/Mag40/val'

create_folders_and_move_images(csv_file_path1, output_folder1)
create_folders_and_move_images(csv_file_path2, output_folder2)
create_folders_and_move_images(csv_file_path3, output_folder3)
